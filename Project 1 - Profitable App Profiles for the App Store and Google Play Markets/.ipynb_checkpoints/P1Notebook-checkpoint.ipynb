# %% [markdown]
# ## Profitable App Profiles for the App Store and Google Play Markets
#
#
# Our goal for this project is to analyze data to help our developers understand what type of apps are likely to attract more users.

# %%
opened_android_file = open('googleplaystore.csv')
opened_ios_file = open('AppleStore.csv')
from csv import reader
read_android_file = reader(opened_android_file)
read_ios_file = reader(opened_ios_file)
android_apps_data = list(read_android_file)
ios_apps_data = list(read_ios_file)

# %%
def explore_data(dataset, start, end, rows_and_columns = False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')
        
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
explore_data(apps_data, 10472, 10473)
# Out:
# ['Xposed Wi-Fi-Pwd', 'PERSONALIZATION', '3.5', '1042', '404k', '100,000+', 'Free', '0', 'Everyone', 'Personalization', 'August 5, 2014', '3.0.0', '4.0.3 and up']

# %% [markdown]
# Problem - Wrong rating for entry 10472

# %%
print(android_apps_data[0])
print(android_apps_data[10472])
# looks like the error doesn't exists at this time, still we will remove the row for safety
del android_apps_data[10472]
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Xposed Wi-Fi-Pwd', 'PERSONALIZATION', '3.5', '1042', '404k', '100,000+', 'Free', '0', 'Everyone', 'Personalization', 'August 5, 2014', '3.0.0', '4.0.3 and up']

# %% [markdown]
# Problem - Duplicate entries for apps

# %%
#let's find out how many apps are repeated
unique_apps = []
duplicate_apps = []
count = 0
for item in android_apps_data[1:]:
    name = item[0]
    if name in unique_apps:
        count += 1
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)

# %%
print(count) #this will tell us how many apps are repeated
print(duplicate_apps) #this will tell us which apps are repeated
# Out:
# 1181
# ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software', 'MailChimp - Email, Marketing Automation', 'Crew - Free Messaging and Scheduling', 'Asana: organize team projects', 'Google Analytics', 'AdWords Express', 'Accounting App - Zoho Books', 'Invoice & Time Tracking - Zoho', 'join.me - Simple Meetings', 'Invoice 2go — Professional Invoices and Estimates', 'SignEasy | Sign and Fill PDF and other Documents', 'Quick PDF Scanner + OCR FREE', 'Genius Scan - PDF Scanner', 'Tiny Scanner - PDF Scanner App', 'Fast Scanner : Free PDF Scan', 'Mobile Doc Scanner (MDScan) Lite', 'TurboScan: scan documents and receipts in PDF', 'Tiny Scanner Pro: PDF Doc Scan', 'Docs To Go™ Free Office Suite', 'OfficeSuite : Free Office + PDF Editor', 'Slack', 'QuickBooks Accounting: Invoicing & Expenses', 'WhatsApp Messenger', 'Messenger – Text and Video Chat for Free', 'imo free video calls and chat', 'Viber Messenger', 'Hangouts', 'WeChat', 'Telegram', 'Who', 'Google Voice', 'Android Messages', 'Firefox Focus: The privacy browser', 'Google Allo', 'Google Chrome: Fast & Secure', 'Firefox Browser fast & private', 'Puffin Web Browser', 'Opera Browser: Fast and Secure', 'Opera Mini - fast web browser', 'UC Browser Mini -Tiny Fast Private & Secure', 'UC Browser - Fast Download Private & Secure', 'Calls & Text by Mo+', 'Viber Messenger', 'Call Blocker', 'Gmail', 'Yahoo Mail – Stay Organized', 'Hangouts', 'imo free video calls and chat', 'free video calls and chat', 'Viber Messenger', 'Skype - free IM & video calls', 'WeChat', 'Glide - Video Chat Messenger', 'Talkray - Free Calls & Texts', 'LINE: Free Calls & Messages', 'KakaoTalk: Free Calls & Text', 'OkCupid Dating', 'CMB Free Dating App', 'Hily: Dating, Chat, Match, Meet & Hook up', 'Hinge: Dating & Relationships', 'BBW Dating & Plus Size Chat', 'Casual Dating & Adult Singles - Joyride', 'EliteSingles – Dating for Single Professionals', 'Clover Dating App', 'Moco - Chat, Meet People', 'Hot or Not - Find someone right now', 'Just She - Top Lesbian Dating', 'Once - Quality Matches Every day', 'Sudy – Meet Elite & Rich Single', 'muzmatch: Muslim & Arab Singles, Marriage & Dating', 'Chispa, the Dating App for Latino, Latina Singles', 'Blendr - Chat, Flirt & Meet', 'Find Real Love — YouLove Premium Dating', 'Cougar Dating Life : Date Older Women Sugar Mummy', 'stranger chat - anonymous chat', 'Millionaire Match: Rich Singles Dating App', 'Dating for 50 plus Mature Singles – FINALLY', 'Moco+ - Chat, Meet People', 'Chat Rooms, Avatars, Date - Galaxy', 'FastMeet: Chat, Dating, Love', 'Christian Dating For Free App', 'Meet24 - Love, Chat, Singles', 'Black White Interracial Dating - Interracial Match', 'Gay Sugar Daddy Dating & Hookup – Sudy Gay', 'Adult Dirty Emojis', 'Hide App, Private Dating, Safe Chat - PrivacyHider', 'Meet4U - Chat, Love, Singles!', '95Live -SG#1 Live Streaming App', 'Just She - Top Lesbian Dating', 'Hily: Dating, Chat, Match, Meet & Hook up', 'O-Star', 'Random Video Chat', 'Black People Meet Singles Date', 'Howlr', 'Free Dating & Flirt Chat - Choice of Love', 'Cardi B Live Stream Video Chat - Prank', 'Chat Kids - Chat Room For Kids', 'muzmatch: Muslim & Arab Singles, Marriage & Dating', 'BBW Dating & Plus Size Chat', 'Transenger – Ts Dating and Chat for Free', 'BBW Dating & Curvy Singles Chat- LargeFriends', 'MouseMingle', 'FlirtChat - ♥Free Dating/Flirting App♥', 'Live Talk - Free Text and Video Chat', 'Adult Dirty Emojis', 'Free Cam Girls - Live Webcam', 'Random Video Chat App With Strangers', 'Live Girls Talk - Free Video Chat', 'Girls Live Chat - Free Text & Video Chat', 'Free Dating App - Meet Local Singles - Flirt Chat', 'iPair-Meet, Chat, Dating', 'Free Dating Hook Up Messenger', 'Free Dating App - YoCutie - Flirt, Chat & M ...

# %%
#let's find the unique apps and remove all repeated data based on the number of reviews. More the reviews means more recent the data was collected.

reviews_max = {}
# reviews have the index 3
for item in android_apps_data[1:]:
    if item[0] in reviews_max:
        if item[3] > reviews_max[item[0]][3]:
            reviews_max[item[0]] = item
    else:
        reviews_max[item[0]] = item
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %%
reviews_max #this dict holds all the unique app names
# Out:
# {'Photo Editor & Candy Camera & Grid & ScrapBook': ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'ART_AND_DESIGN',
#   '4.1',
#   '159',
#   '19M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 7, 2018',
#   '1.0.0',
#   '4.0.3 and up'],
#  'Coloring book moana': ['Coloring book moana',
#   'FAMILY',
#   '3.9',
#   '974',
#   '14M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Pretend Play',
#   'January 15, 2018',
#   '2.0.0',
#   '4.0.3 and up'],
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps': ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'ART_AND_DESIGN',
#   '4.7',
#   '87510',
#   '8.7M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 1, 2018',
#   '1.2.4',
#   '4.0.3 and up'],
#  'Sketch - Draw & Paint': ['Sketch - Draw & Paint',
#   'ART_AND_DESIGN',
#   '4.5',
#   '215644',
#   '25M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Art & Design',
#   'June 8, 2018',
#   'Varies with device',
#   '4.2 and up'],
#  'Pixel Draw - Number Art Coloring Book': ['Pixel Draw - Number Art Coloring Book',
#   'ART_AND_DESIGN',
#   '4.3',
#   '967',
#   '2.8M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'June 20, 2018',
#   '1.1',
#   '4.4 and up'],
#  'Paper flowers instructions': ['Paper flowers instructions',
#   'ART_AND_DESIGN',
#   '4.4',
#   '167',
#   '5.6M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'March 26, 2017',
#   '1.0',
#   '2.3 and up'],
#  'Smoke Effect Photo Maker - Smoke Editor': ['Smoke Effect Photo Maker - Smoke Editor',
#   'ART_AND_DESIGN',
#   '3.8',
#   '178',
#   '19M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'April 26, 2018',
#   '1.1',
#   '4.0.3 and up'],
#  'Infinite Painter': ['Infinite Painter',
#   'ART_AND_DESIGN',
#   '4.1',
#   '36815',
#   '29M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'June 14, 2018',
#   '6.1.61.1',
#   '4.2 and up'],
#  'Garden Coloring Book': ['Garden Coloring Book',
#   'ART_AND_DESIGN',
#   '4.4',
#   '13791',
#   '33M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'September 20, 2017',
#   '2.9.2',
#   '3.0 and up'],
#  'Kids Paint Free - Drawing Fun': ['Kids Paint Free - Drawing Fun',
#   'ART_AND_DESIGN',
#   '4.7',
#   '121',
#   '3.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'July 3, 2018',
#   '2.8',
#   '4.0.3 and up'],
#  'Text on Photo - Fonteee': ['Text on Photo - Fonteee',
#   'ART_AND_DESIGN',
#   '4.4',
#   '13880',
#   '28M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'October 27, 2017',
#   '1.0.4',
#   '4.1 and up'],
#  'Name Art Photo Editor - Focus n Filters': ['Name Art Photo Editor - Focus n Filters',
#   'ART_AND_DESIGN',
#   '4.4',
#   '8788',
#   '12M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 31, 2018',
#   '1.0.15',
#   '4.0 and up'],
#  'Tattoo Name On My Photo Editor': ['Tattoo Name On My Photo Editor',
#   'ART_AND_DESIGN',
#   '4.2',
#   '44829',
#   '20M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Art & Design',
#   'April 2, 2018',
#   '3.8',
#   '4.1 and up'],
#  'Mandala Coloring Book': ['Mandala Coloring Book',
#   'ART_AND_DESIGN',
#   '4.6',
#   '4326',
#   '21M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'June 26, 2018',
#   '1.0.4',
#   '4.4 and up'],
#  '3D Color Pixel by Number - Sandbox Art Coloring': ['3D Color Pixel by Number - Sandbox Art Coloring',
#   'ART_AND_DESIGN',
#   '4.4',
#   '1518',
#   '37M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 3, 2018',
#   '1.2.3',
#   '2.3 and up'],
#  'Learn To Draw Kawaii Characters': ['Learn To Draw Kawaii Characters',
#   'ART_AND_DESIGN',
#   '3.2',
#   '55',
#   '2.7M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'June 6, 2018',
#   'NaN',
#   '4.2 and up'],
#  'Photo Designer - Write your name with shapes': ['Photo Designer - Write your name with shapes',
#   'ART_AND_DESIGN',
#   '4.7',
#   '3632',
#   '5.5M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 31, 2018',
#   '3.1',
#   '4.1 and up'],
#  '350 Diy Room Decor Ideas': ['350 Diy Room Decor Ideas',
#   'ART_AND_DESIGN',
#   '4.5',
#   '27',
#   '17M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'November 7, 2017',
#   '1.0',
#   '2.3 and up'],
#  'FlipaClip - Cartoon animation': ['FlipaClip - Cartoon animation',
#   'ART_AND_DESIGN',
#   '4.3',
#   '194216',
#   '39M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 3, 2018',
#   '2.2.5',
#   '4.0.3 and up'],
#  'ibis Paint X': ['ibis Paint X',
#   'ART_AND_DESIGN',
#   '4.6',
#   '224399',
#   '31M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 30, 2018',
#   '5.5.4',
#   '4.1 and up'],
#  'Logo Maker - Small Business': ['Logo Maker - Small Business',
#   'ART_AND_DESIGN',
#   '4.0',
#   '450',
#   '14M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'April 20, 2018',
#   '4.0',
#   '4.1 and up'],
#  "Boys Photo Editor - Six Pack & Men's Suit": ["Boys Photo Editor - Six Pack & Men's Suit",
#   'ART_AND_DESIGN',
#   '4.1',
#   '654',
#   '12M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'March 20, 2018',
#   '1.1',
#   '4.0.3 and up'],
#  'Superheroes Wallpapers | 4K Backgrounds': ['Superheroes Wallpapers | 4K Backgrounds',
#   'ART_AND_DESIGN',
#   '4.7',
#   '7699',
#   '4.2M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Art & Design',
#   'July 12, 2018',
#   '2.2.6.2',
#   '4.0.3 and up'],
#  'Mcqueen Coloring pages': ['Mcqueen Coloring pages',
#   'FAMILY',
#   'NaN',
#   '65',
#   '7.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Action & Adventure',
#   'March 7, 2018',
#   '1.0.0',
#   '4.1 and up'],
#  'HD Mickey Minnie Wallpapers': ['HD Mickey Minnie Wallpapers',
#   'ART_AND_DESIGN',
#   '4.7',
#   '118',
#   '23M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 7, 2018',
#   '1.1.3',
#   '4.1 and up'],
#  'Harley Quinn wallpapers HD': ['Harley Quinn wallpapers HD',
#   'ART_AND_DESIGN',
#   '4.8',
#   '192',
#   '6.0M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'April 25, 2018',
#   '1.5',
#   '3.0 and up'],
#  'Colorfit - Drawing & Coloring': ['Colorfit - Drawing & Coloring',
#   'ART_AND_DESIGN',
#   '4.7',
#   '20260',
#   '25M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'October 11, 2017',
#   '1.0.8',
#   '4.0.3 and up'],
#  'Animated Photo Editor': ['Animated Photo Editor',
#   'ART_AND_DESIGN',
#   '4.1',
#   '203',
#   '6.1M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'March 21, 2018',
#   '1.03',
#   '4.0.3 and up'],
#  'Pencil Sketch Drawing': ['Pencil Sketch Drawing',
#   'ART_AND_DESIGN',
#   '3.9',
#   '136',
#   '4.6M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 12, 2018',
#   '6.0',
#   '2.3 and up'],
#  'Easy Realistic Drawing Tutorial': ['Easy Realistic Drawing Tutorial',
#   'ART_AND_DESIGN',
#   '4.1',
#   '223',
#   '4.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 22, 2017',
#   '1.0',
#   '2.3 and up'],
#  'Pink Silver Bow Keyboard Theme': ['Pink Silver Bow Keyboard Theme',
#   'ART_AND_DESIGN',
#   '4.2',
#   '1120',
#   '9.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 12, 2018',
#   '6.7.12.2018',
#   '4.0.3 and up'],
#  'Art Drawing Ideas': ['Art Drawing Ideas',
#   'ART_AND_DESIGN',
#   '4.1',
#   '227',
#   '5.2M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'May 31, 2018',
#   '1.2',
#   '2.3 and up'],
#  'Anime Manga Coloring Book': ['Anime Manga Coloring Book',
#   'ART_AND_DESIGN',
#   '4.5',
#   '5035',
#   '11M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 19, 2018',
#   '2.20',
#   '4.0 and up'],
#  'Easy Origami Ideas': ['Easy Origami Ideas',
#   'ART_AND_DESIGN',
#   '4.2',
#   '1015',
#   '11M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 6, 2018',
#   '1.1.0',
#   '4.1 and up'],
#  'I Creative Idea': ['I Creative Idea',
#   'ART_AND_DESIGN',
#   '4.7',
#   '353',
#   '4.2M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Art & Design',
#   'April 27, 2018',
#   '1.6',
#   '4.1 and up'],
#  'How to draw Ladybug and Cat Noir': ['How to draw Ladybug and Cat Noir',
#   'ART_AND_DESIGN',
#   '3.8',
#   '564',
#   '9.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 11, 2018',
#   '2.1',
#   '4.1 and up'],
#  'UNICORN - Color By Number & Pixel Art Coloring': ['UNICORN - Color By Number & Pixel Art Coloring',
#   'FAMILY',
#   '4.7',
#   '8264',
#   '24M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'August 2, 2018',
#   '1.0.9',
#   '4.4 and up'],
#  'Floor Plan Creator': ['Floor Plan Creator',
#   'ART_AND_DESIGN',
#   '4.1',
#   '36639',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 14, 2018',
#   'Varies with device',
#   '2.3.3 and up'],
#  'PIP Camera - PIP Collage Maker': ['PIP Camera - PIP Collage Maker',
#   'ART_AND_DESIGN',
#   '4.7',
#   '158',
#   '11M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'November 29, 2017',
#   '1.3',
#   '4.0.3 and up'],
#  'How To Color Disney Princess - Coloring Pages': ['How To Color Disney Princess - Coloring Pages',
#   'ART_AND_DESIGN',
#   '4.0',
#   '591',
#   '9.4M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'March 31, 2018',
#   '1',
#   '4.0 and up'],
#  'Drawing Clothes Fashion Ideas': ['Drawing Clothes Fashion Ideas',
#   'ART_AND_DESIGN',
#   '4.2',
#   '117',
#   '15M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 20, 2018',
#   '2.0.1',
#   '4.0.3 and up'],
#  'Sad Poetry Photo Frames 2018': ['Sad Poetry Photo Frames 2018',
#   'ART_AND_DESIGN',
#   '4.5',
#   '176',
#   '10M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'April 2, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  'Textgram - write on photos': ['Textgram - write on photos',
#   'ART_AND_DESIGN',
#   '4.4',
#   '295237',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Paint Splash!': ['Paint Splash!',
#   'ART_AND_DESIGN',
#   '3.8',
#   '2206',
#   '1.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'April 15, 2018',
#   '1.46',
#   '4.1 and up'],
#  'Popsicle Sticks and Similar DIY Craft Ideas': ['Popsicle Sticks and Similar DIY Craft Ideas',
#   'ART_AND_DESIGN',
#   '4.2',
#   '26',
#   '12M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 3, 2018',
#   '1.0.0',
#   '4.1 and up'],
#  'Canva: Poster, banner, card maker & graphic design': ['Canva: Poster, banner, card maker & graphic design',
#   'ART_AND_DESIGN',
#   '4.7',
#   '174531',
#   '24M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'July 31, 2018',
#   '1.6.1',
#   '4.1 and up'],
#  'Install images with music to make video without Net - 2018': ['Install images with music to make video without Net - 2018',
#   'ART_AND_DESIGN',
#   '4.6',
#   '1070',
#   '26M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'November 14, 2017',
#   '1.6',
#   '4.1 and up'],
#  'Little Teddy Bear Colouring Book Game': ['Little Teddy Bear Colouring Book Game',
#   'ART_AND_DESIGN',
#   '4.2',
#   '85',
#   '8.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'December 17, 2017',
#   '2.0.0',
#   '4.1 and up'],
#  'How To Draw Food': ['How To Draw Food',
#   'ART_AND_DESIGN',
#   '4.3',
#   '845',
#   '7.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'May 28, 2018',
#   '1.0',
#   '2.3 and up'],
#  'Monster Truck Stunt 3D 2019': ['Monster Truck Stunt 3D 2019',
#   'AUTO_AND_VEHICLES',
#   '4.2',
#   '367',
#   '25M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'May 10, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  'Real Tractor Farming': ['Real Tractor Farming',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '1598',
#   '56M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 26, 2018',
#   '11.0',
#   '4.1 and up'],
#  'Ultimate F1 Racing Championship': ['Ultimate F1 Racing Championship',
#   'AUTO_AND_VEHICLES',
#   '3.8',
#   '284',
#   '57M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 26, 2018',
#   '3.0',
#   '4.1 and up'],
#  'Used Cars and Trucks for Sale': ['Used Cars and Trucks for Sale',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '17057',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'American Muscle Car Race': ['American Muscle Car Race',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '129',
#   '35M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 26, 2018',
#   '3.0',
#   '4.1 and up'],
#  'Offroad Oil Tanker Driver Transport Truck 2019': ['Offroad Oil Tanker Driver Transport Truck 2019',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '542',
#   '33M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 31, 2018',
#   '4.0',
#   '4.1 and up'],
#  'Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru': ['Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru',
#   'AUTO_AND_VEHICLES',
#   '4.9',
#   '10479',
#   '33M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 18, 2018',
#   '1.7.1',
#   '4.0 and up'],
#  'Gas Prices (Germany only)': ['Gas Prices (Germany only)',
#   'AUTO_AND_VEHICLES',
#   '4.4',
#   '805',
#   '5.6M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 29, 2018',
#   '2.5.1',
#   '4.4 and up'],
#  'Extreme Rally Championship': ['Extreme Rally Championship',
#   'AUTO_AND_VEHICLES',
#   '4.2',
#   '129',
#   '54M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 26, 2018',
#   '3.0',
#   '4.1 and up'],
#  'Restart Navigator': ['Restart Navigator',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '1403',
#   '201k',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 26, 2014',
#   '1.0.1',
#   '2.2 and up'],
#  'REG - Check the regnumber, find information about Swedish vehicles': ['REG - Check the regnumber, find information about Swedish vehicles',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '3971',
#   '3.6M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   '2.493',
#   '4.4 and up'],
#  'CityBus Lviv': ['CityBus Lviv',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '534',
#   '5.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 8, 2018',
#   '1.9.1',
#   '4.0.3 and up'],
#  'CDL Practice Test 2018 Edition': ['CDL Practice Test 2018 Edition',
#   'AUTO_AND_VEHICLES',
#   '4.9',
#   '7774',
#   '17M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 3, 2018',
#   '1.7',
#   '4.2 and up'],
#  'ezETC (ETC balance inquiry, meter trial, real-time traffic)': ['ezETC (ETC balance inquiry, meter trial, real-time traffic)',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '38846',
#   '8.6M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 28, 2018',
#   '2.20 Build 02',
#   '4.1 and up'],
#  'Free VIN Report for Used Cars': ['Free VIN Report for Used Cars',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '2431',
#   '2.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'June 12, 2018',
#   '1.37',
#   '4.0 and up'],
#  'DMV Permit Practice Test 2018 Edition': ['DMV Permit Practice Test 2018 Edition',
#   'AUTO_AND_VEHICLES',
#   '4.9',
#   '6090',
#   '27M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 3, 2018',
#   '1.7',
#   '4.2 and up'],
#  'Check Vehicle Tax': ['Check Vehicle Tax',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '295',
#   '2.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   '0.2.1',
#   '4.4 and up'],
#  'Used Cars Mexico': ['Used Cars Mexico',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '190',
#   '2.5M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'October 14, 2016',
#   '1.0',
#   '2.3 and up'],
#  'Ulysse Speedometer': ['Ulysse Speedometer',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '40211',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'REPUVE': ['REPUVE',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '356',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'May 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Used cars for sale - Trovit': ['Used cars for sale - Trovit',
#   'AUTO_AND_VEHICLES',
#   '4.2',
#   '52530',
#   '7.0M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 16, 2018',
#   '4.47.3',
#   '4.0.3 and up'],
#  'Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines': ['Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines',
#   'AUTO_AND_VEHICLES',
#   '4.8',
#   '116986',
#   '35M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 2, 2018',
#   '1.9.7',
#   '4.0.3 and up'],
#  'SK Enca Direct Malls - Used Cars Search': ['SK Enca Direct Malls - Used Cars Search',
#   'AUTO_AND_VEHICLES',
#   '3.6',
#   '1379',
#   '16M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 2, 2018',
#   '2.2.21',
#   '4.2 and up'],
#  'Android Auto - Maps, Media, Messaging & Voice': ['Android Auto - Maps, Media, Messaging & Voice',
#   'AUTO_AND_VEHICLES',
#   '4.2',
#   '271920',
#   '16M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Auto & Vehicles',
#   'July 11, 2018',
#   'Varies with device',
#   '5.0 and up'],
#  'PDD-UA': ['PDD-UA',
#   'AUTO_AND_VEHICLES',
#   '4.8',
#   '736',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 29, 2018',
#   '2.9',
#   '2.3.3 and up'],
#  'Tickets SDA 2019 + Exam RF': ['Tickets SDA 2019 + Exam RF',
#   'AUTO_AND_VEHICLES',
#   '4.8',
#   '7021',
#   '17M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 27, 2018',
#   '1.79',
#   '4.0 and up'],
#  'Super Cars Wallpapers And Backgrounds': ['Super Cars Wallpapers And Backgrounds',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '197',
#   '3.4M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'June 14, 2018',
#   '1.3',
#   '4.0 and up'],
#  'Police Lights, Sirens & Follow Me': ['Police Lights, Sirens & Follow Me',
#   'AUTO_AND_VEHICLES',
#   '4.5',
#   '737',
#   '8.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'June 8, 2018',
#   '2.3.5.1',
#   '4.1 and up'],
#  'Police Detector (Speed Camera Radar)': ['Police Detector (Speed Camera Radar)',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '3574',
#   '3.9M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Auto & Vehicles',
#   'July 4, 2018',
#   '1.6',
#   '4.0 and up'],
#  'Best Car Wallpapers': ['Best Car Wallpapers',
#   'AUTO_AND_VEHICLES',
#   '4.5',
#   '994',
#   '2.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'March 27, 2018',
#   '1.6',
#   '4.1 and up'],
#  'Tickets + PDA 2018 Exam': ['Tickets + PDA 2018 Exam',
#   'AUTO_AND_VEHICLES',
#   '4.9',
#   '197136',
#   '38M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 15, 2018',
#   '8.31',
#   '4.1 and up'],
#  'Pick Your Part Garage': ['Pick Your Part Garage',
#   'AUTO_AND_VEHICLES',
#   '3.9',
#   '142',
#   '32M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 24, 2018',
#   '1.1.5.0',
#   '6.0 and up'],
#  'PakWheels: Buy & Sell Cars': ['PakWheels: Buy & Sell Cars',
#   'AUTO_AND_VEHICLES',
#   '4.4',
#   '15168',
#   '37M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 27, 2018',
#   '10.0.2',
#   '4.2 and up'],
#  'Supervision service': ['Supervision service',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '2155',
#   '15M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 30, 2018',
#   '1.10.3',
#   '5.0 and up'],
#  'Speed Camera Detector - Traffic & Speed Alert': ['Speed Camera Detector - Traffic & Speed Alert',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '138',
#   '5.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 23, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  'Used car search Goo net whole car Go to net': ['Used car search Goo net whole car Go to net',
#   'AUTO_AND_VEHICLES',
#   '3.7',
#   '5414',
#   '18M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 23, 2018',
#   '3.20.1',
#   '4.4 and up'],
#  'CarMax – Cars for Sale: Search Used Car Inventory': ['CarMax – Cars for Sale: Search Used Car Inventory',
#   'AUTO_AND_VEHICLES',
#   '4.4',
#   '21777',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 4, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'BEST CAR SOUNDS': ['BEST CAR SOUNDS',
#   'AUTO_AND_VEHICLES',
#   '4.3',
#   '348',
#   '38M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 29, 2018',
#   '1.0.3',
#   '2.3 and up'],
#  'RST - Sale of cars on the PCT': ['RST - Sale of cars on the PCT',
#   'AUTO_AND_VEHICLES',
#   '3.2',
#   '250',
#   '1.1M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'April 27, 2018',
#   '1.4',
#   '4.0.3 and up'],
#  'AutoScout24 Switzerland – Find your new car': ['AutoScout24 Switzerland – Find your new car',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '13372',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo': ['Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '7880',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'May 10, 2018',
#   '4.6.5',
#   'Varies with device'],
#  'SMS Park': ['SMS Park',
#   'AUTO_AND_VEHICLES',
#   '4.5',
#   '3617',
#   '7.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'May 16, 2018',
#   '2.8.2',
#   '4.1 and up'],
#  'SKencar': ['SKencar',
#   'AUTO_AND_VEHICLES',
#   '3.7',
#   '4806',
#   '35M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 31, 2018',
#   '4.0.3',
#   '4.0.3 and up'],
#  'Fuelio: Gas log & costs': ['Fuelio: Gas log & costs',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '65786',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 2, 2018',
#   'Varies with device',
#   '4.0.3 and up'],
#  'auto fines': ['auto fines',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '31433',
#   '17M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'August 2, 2018',
#   '1.40',
#   '4.0.3 and up'],
#  'Used car is the first car - used car purchase, used car quotation, dealer information to': ['Used car is the first car - used car purchase, used car quotation, dealer information to',
#   'AUTO_AND_VEHICLES',
#   '4.6',
#   '5097',
#   '19M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'July 23, 2018',
#   '1.5.18',
#   '4.0.3 and up'],
#  'All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)': ['All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '1754',
#   '14M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'June 2, 2018',
#   '2.3.4',
#   '4.0 and up'],
#  'Inquiry Fines and Debits of Vehicles': ['Inquiry Fines and Debits of Vehicles',
#   'AUTO_AND_VEHICLES',
#   '4.4',
#   '2680',
#   '2.2M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'March 20, 2018',
#   '1.03',
#   '4.0.3 and up'],
#  'Gas Station': ['Gas Station',
#   'AUTO_AND_VEHICLES',
#   '4.0',
#   '1288',
#   '4.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Auto & Vehicles',
#   'April 21, 2018',
#   '2.17',
#   '4.0 and up'],
#  'Hush - Beauty for Everyone': ['Hush - Beauty for Everyone',
#   'BEAUTY',
#   '4.7',
#   '18900',
#   '17M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'August 2, 2018',
#   '6.10.1',
#   '5.0 and up'],
#  'ipsy: Makeup, Beauty, and Tips': ['ipsy: Makeup, Beauty, and Tips',
#   'BEAUTY',
#   '4.9',
#   '49790',
#   '14M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'November 9, 2017',
#   '2.3.0',
#   '4.1 and up'],
#  'Natural recipes for your beauty': ['Natural recipes for your beauty',
#   'BEAUTY',
#   '4.7',
#   '1150',
#   '9.8M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 15, 2018',
#   '4.0',
#   '4.1 and up'],
#  'BestCam Selfie-selfie, beauty camera, photo editor': ['BestCam Selfie-selfie, beauty camera, photo editor',
#   'BEAUTY',
#   '3.9',
#   '1739',
#   '21M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 12, 2018',
#   '1.0.6',
#   '4.0.3 and up'],
#  'Mirror - Zoom & Exposure -': ['Mirror - Zoom & Exposure -',
#   'BEAUTY',
#   '3.9',
#   '32090',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'October 24, 2016',
#   'Varies with device',
#   'Varies with device'],
#  'Beauty Selfie Camera': ['Beauty Selfie Camera',
#   'BEAUTY',
#   '4.2',
#   '2225',
#   '52M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'February 28, 2018',
#   '1.6',
#   '4.1 and up'],
#  'Hairstyles step by step': ['Hairstyles step by step',
#   'BEAUTY',
#   '4.6',
#   '4369',
#   '14M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 25, 2018',
#   '1.9',
#   '4.0.3 and up'],
#  'Filters for Selfie': ['Filters for Selfie',
#   'BEAUTY',
#   '4.3',
#   '8572',
#   '25M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 10, 2018',
#   '1.1.0',
#   '4.0 and up'],
#  'Tie - Always be happy': ['Tie - Always be happy',
#   'BEAUTY',
#   '4.7',
#   '964',
#   '9.0M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 21, 2018',
#   '4.0',
#   '4.2 and up'],
#  'Ulta Beauty': ['Ulta Beauty',
#   'BEAUTY',
#   '4.7',
#   '42050',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 5, 2018',
#   '5.4',
#   '5.0 and up'],
#  'Prom MakeUp Tutorial': ['Prom MakeUp Tutorial',
#   'BEAUTY',
#   '4.8',
#   '104',
#   '12M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 26, 2018',
#   '1.3',
#   '4.0.3 and up'],
#  'Selfie Camera': ['Selfie Camera',
#   'BEAUTY',
#   '4.2',
#   '17934',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'September 12, 2017',
#   'Varies with device',
#   'Varies with device'],
#  'Sweet Selfie Beauty Camera': ['Sweet Selfie Beauty Camera',
#   'BEAUTY',
#   '4.3',
#   '601',
#   '35M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 2, 2018',
#   '2.0.0',
#   '4.0 and up'],
#  'Colors of white in Urdu': ['Colors of white in Urdu',
#   'BEAUTY',
#   '4.5',
#   '36',
#   '6.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 26, 2018',
#   '6.0',
#   '4.0 and up'],
#  'Selfie Camera Photo Editor & Filter & Sticker': ['Selfie Camera Photo Editor & Filter & Sticker',
#   'BEAUTY',
#   '4.1',
#   '187',
#   '30M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Beauty',
#   'July 24, 2018',
#   '3.0.1',
#   '4.0.3 and up'],
#  'Wrinkles and rejuvenation': ['Wrinkles and rejuvenation',
#   'BEAUTY',
#   'NaN',
#   '182',
#   '5.7M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Beauty',
#   'September 20, 2017',
#   '8.0',
#   '3.0 and up'],
#  'Eyes Makeup Beauty Tips': ['Eyes Makeup Beauty Tips',
#   'BEAUTY',
#   '4.2',
#   '30',
#   '2.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'April 9, 2018',
#   '3.3.9',
#   '4.0.3 and up'],
#  'Photo Editor 2018': ['Photo Editor 2018',
#   'BEAUTY',
#   '4.5',
#   '134',
#   '17M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'March 1, 2018',
#   '1.20',
#   '4.0.3 and up'],
#  'Step By Step Eyes Makeup Tutorial': ['Step By Step Eyes Makeup Tutorial',
#   'BEAUTY',
#   '4.4',
#   '74',
#   '2.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'April 5, 2018',
#   '2.3.09',
#   '4.0.3 and up'],
#  'Beauty Camera - Selfie Camera': ['Beauty Camera - Selfie Camera',
#   'BEAUTY',
#   '4.0',
#   '113715',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'August 3, 2017',
#   'Varies with device',
#   'Varies with device'],
#  'Girls Hairstyles': ['Girls Hairstyles',
#   'BEAUTY',
#   '4.1',
#   '3595',
#   'Varies with device',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 24, 2018',
#   'Varies with device',
#   '4.0 and up'],
#  'Mirror Camera (Mirror + Selfie Camera)': ['Mirror Camera (Mirror + Selfie Camera)',
#   'BEAUTY',
#   '4.1',
#   '9315',
#   '2.6M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'November 21, 2017',
#   '1.4.2',
#   '4.0 and up'],
#  'Beauty Tips - Beauty Tips in Sinhala': ['Beauty Tips - Beauty Tips in Sinhala',
#   'BEAUTY',
#   '4.4',
#   '75',
#   '4.2M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'October 18, 2017',
#   '1.0.0',
#   '4.0.3 and up'],
#  'Haircut Tutorials/Haircut Videos': ['Haircut Tutorials/Haircut Videos',
#   'BEAUTY',
#   '4.6',
#   '38',
#   '7.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 29, 2018',
#   '1.0',
#   '4.0 and up'],
#  'Sephora: Skin Care, Beauty Makeup & Fragrance Shop': ['Sephora: Skin Care, Beauty Makeup & Fragrance Shop',
#   'BEAUTY',
#   '4.5',
#   '26834',
#   '57M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 24, 2018',
#   '18.5',
#   '5.0 and up'],
#  'Manicure - nail design': ['Manicure - nail design',
#   'BEAUTY',
#   'NaN',
#   '119',
#   '3.7M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 23, 2018',
#   '1.3',
#   '4.1 and up'],
#  'Sticker Camera - Selfie Filters, Beauty Camera': ['Sticker Camera - Selfie Filters, Beauty Camera',
#   'BEAUTY',
#   '3.9',
#   '2277',
#   '22M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 12, 2018',
#   '1.1.0',
#   '4.0.3 and up'],
#  'Filters for B Live': ['Filters for B Live',
#   'BEAUTY',
#   '4.4',
#   '2280',
#   '24M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 14, 2018',
#   '1.1.0',
#   '4.0 and up'],
#  'Skin Care and Natural Beauty': ['Skin Care and Natural Beauty',
#   'BEAUTY',
#   'NaN',
#   '654',
#   '7.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Beauty',
#   'July 17, 2018',
#   '1.15',
#   '4.1 and up'],
#  'Facial Wrinkle Reduction': ['Facial Wrinkle Reduction',
#   'BEAUTY',
#   '4.6',
#   '184',
#   '21M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 2, 2018',
#   '1.5',
#   '4.1 and up'],
#  'Makeup Videos': ['Makeup Videos',
#   'BEAUTY',
#   '3.8',
#   '9',
#   '3.4M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 7, 2018',
#   '1.0',
#   '4.0 and up'],
#  'Secrets of beauty, youth and health': ['Secrets of beauty, youth and health',
#   'BEAUTY',
#   'NaN',
#   '77',
#   '2.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Beauty',
#   'August 8, 2017',
#   '2.0',
#   '2.3 and up'],
#  'Recipes and tips for losing weight': ['Recipes and tips for losing weight',
#   'BEAUTY',
#   'NaN',
#   '35',
#   '3.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Beauty',
#   'December 11, 2017',
#   '2.0',
#   '3.0 and up'],
#  'Discover Color': ['Discover Color',
#   'BEAUTY',
#   '4.0',
#   '364',
#   '6.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 24, 2018',
#   '1.1',
#   '4.0.3 and up'],
#  'Eyeliner step by step 2018': ['Eyeliner step by step 2018',
#   'BEAUTY',
#   '4.3',
#   '18',
#   '3.2M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'June 1, 2018',
#   '1.2.13',
#   '4.0.3 and up'],
#  'Dresses Ideas & Fashions +3000': ['Dresses Ideas & Fashions +3000',
#   'BEAUTY',
#   '4.5',
#   '473',
#   '8.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Beauty',
#   'March 1, 2017',
#   '1.0.2.0',
#   '1.6 and up'],
#  'Lady adviser (beauty, health)': ['Lady adviser (beauty, health)',
#   'BEAUTY',
#   'NaN',
#   '30',
#   '9.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Beauty',
#   'January 24, 2018',
#   '3.0',
#   '3.0 and up'],
#  'Step By Step Hairstyles For Women': ['Step By Step Hairstyles For Women',
#   'BEAUTY',
#   '4.1',
#   '66',
#   '2.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'April 5, 2018',
#   '3.1.89',
#   '4.0.3 and up'],
#  'Rainbow Camera': ['Rainbow Camera',
#   'BEAUTY',
#   '3.7',
#   '3871',
#   '23M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'July 30, 2018',
#   '2.2.0',
#   '4.0 and up'],
#  'Methods of teeth whitening': ['Methods of teeth whitening',
#   'BEAUTY',
#   '4.7',
#   '257',
#   '4.6M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'August 7, 2017',
#   '1.0',
#   '4.0.3 and up'],
#  'Girls hairstyles 2018': ['Girls hairstyles 2018',
#   'BEAUTY',
#   '4.2',
#   '62',
#   '3.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Beauty',
#   'May 28, 2018',
#   '1.9.2',
#   '4.0.3 and up'],
#  'Wattpad 📖 Free Books': ['Wattpad 📖 Free Books',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '2915189',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'E-Book Read - Read Book for free': ['E-Book Read - Read Book for free',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '1857',
#   '4.9M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 3, 2018',
#   '1.3.2',
#   '4.4 and up'],
#  'Download free book with green book': ['Download free book with green book',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '4478',
#   '9.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Books & Reference',
#   'July 31, 2017',
#   '1.1',
#   '4.0 and up'],
#  'Wikipedia': ['Wikipedia',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '577550',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Amazon Kindle': ['Amazon Kindle',
#   'BOOKS_AND_REFERENCE',
#   '4.2',
#   '814151',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'July 27, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Cool Reader': ['Cool Reader',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '246315',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 17, 2015',
#   'Varies with device',
#   '1.5 and up'],
#  'Dictionary - Merriam-Webster': ['Dictionary - Merriam-Webster',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '454412',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'May 18, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'NOOK: Read eBooks & Magazines': ['NOOK: Read eBooks & Magazines',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '155466',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'April 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Free Panda Radio Music': ['Free Panda Radio Music',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '418',
#   '4.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'March 27, 2018',
#   '2.1',
#   '4.1 and up'],
#  'Book store': ['Book store',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '22486',
#   '5.4M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'June 6, 2018',
#   '3.2.1',
#   '4.0 and up'],
#  'FBReader: Favorite Book Reader': ['FBReader: Favorite Book Reader',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '203130',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 28, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'English Grammar Complete Handbook': ['English Grammar Complete Handbook',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '1435',
#   '2.8M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'January 21, 2018',
#   '1.0',
#   '4.0 and up'],
#  'Free Books - Spirit Fanfiction and Stories': ['Free Books - Spirit Fanfiction and Stories',
#   'BOOKS_AND_REFERENCE',
#   '4.8',
#   '116507',
#   '5.0M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'August 1, 2018',
#   '2.0.075',
#   '4.0.3 and up'],
#  'Google Play Books': ['Google Play Books',
#   'BOOKS_AND_REFERENCE',
#   '3.9',
#   '1433233',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'AlReader -any text book reader': ['AlReader -any text book reader',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '90468',
#   '5.9M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'May 27, 2018',
#   '1.911805270',
#   '2.3 and up'],
#  'Offline English Dictionary': ['Offline English Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.2',
#   '860',
#   '13M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 17, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  'Oxford Dictionary of English : Free': ['Oxford Dictionary of English : Free',
#   'BOOKS_AND_REFERENCE',
#   '4.1',
#   '364452',
#   '7.1M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 11, 2018',
#   '9.1.363',
#   '4.1 and up'],
#  'Offline: English to Tagalog Dictionary': ['Offline: English to Tagalog Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.7',
#   '967',
#   '6.7M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 4, 2018',
#   '1.1.6',
#   '4.0.3 and up'],
#  'Spanish English Translator': ['Spanish English Translator',
#   'BOOKS_AND_REFERENCE',
#   '4.2',
#   '87919',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'May 28, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'FamilySearch Tree': ['FamilySearch Tree',
#   'BOOKS_AND_REFERENCE',
#   '4.3',
#   '17506',
#   '17M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 20, 2018',
#   '2.3.18',
#   '4.1 and up'],
#  'Cloud of Books': ['Cloud of Books',
#   'BOOKS_AND_REFERENCE',
#   '3.3',
#   '1862',
#   '19M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'April 27, 2018',
#   '2.2.5',
#   '4.1 and up'],
#  'Recipes of Prophetic Medicine for free': ['Recipes of Prophetic Medicine for free',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '2084',
#   '6.7M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'May 17, 2018',
#   '15.0',
#   '2.3 and up'],
#  'ReadEra – free ebook reader': ['ReadEra – free ebook reader',
#   'BOOKS_AND_REFERENCE',
#   '4.8',
#   '47303',
#   '21M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 2, 2018',
#   '18.05.31+530',
#   '4.1 and up'],
#  'NOOK App for NOOK Devices': ['NOOK App for NOOK Devices',
#   'BOOKS_AND_REFERENCE',
#   '4.7',
#   '19090',
#   'Varies with device',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'April 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Anonymous caller detection': ['Anonymous caller detection',
#   'BOOKS_AND_REFERENCE',
#   'NaN',
#   '161',
#   '2.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 13, 2018',
#   '1.0',
#   '2.3 and up'],
#  'Ebook Reader': ['Ebook Reader',
#   'BOOKS_AND_REFERENCE',
#   '4.1',
#   '85842',
#   '37M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 25, 2018',
#   '5.0.6',
#   '4.0 and up'],
#  'Litnet - E-books': ['Litnet - E-books',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '7831',
#   '15M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Books & Reference',
#   'July 4, 2018',
#   '1.2.3',
#   '4.0 and up'],
#  'Read books online': ['Read books online',
#   'BOOKS_AND_REFERENCE',
#   '4.1',
#   '91615',
#   '23M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Books & Reference',
#   'June 29, 2018',
#   '3.12',
#   '4.1 and up'],
#  'English to Urdu Dictionary': ['English to Urdu Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '4620',
#   '19M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'November 23, 2017',
#   '2.0',
#   '4.0.3 and up'],
#  'eBoox: book reader fb2 epub zip': ['eBoox: book reader fb2 epub zip',
#   'BOOKS_AND_REFERENCE',
#   '4.7',
#   '21336',
#   '23M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 20, 2018',
#   '1.28',
#   '3.0 and up'],
#  'English Persian Dictionary': ['English Persian Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '26875',
#   '73M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 1, 2018',
#   '6.0.8',
#   '4.0.3 and up'],
#  'Flybook': ['Flybook',
#   'BOOKS_AND_REFERENCE',
#   '3.9',
#   '1778',
#   '4.9M',
#   '500,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Books & Reference',
#   'October 16, 2014',
#   '1.0.3',
#   '2.1 and up'],
#  'All Maths Formulas': ['All Maths Formulas',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '2709',
#   '6.8M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 11, 2018',
#   '1.9',
#   '4.4 and up'],
#  'Ancestry': ['Ancestry',
#   'BOOKS_AND_REFERENCE',
#   '4.3',
#   '64513',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 31, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'HTC Help': ['HTC Help',
#   'BOOKS_AND_REFERENCE',
#   '4.2',
#   '8342',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 28, 2017',
#   '9.00.950462',
#   '7.0 and up'],
#  'English translation from Bengali': ['English translation from Bengali',
#   'BOOKS_AND_REFERENCE',
#   '4.5',
#   '527',
#   '2.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'March 31, 2018',
#   '14.0',
#   '4.0 and up'],
#  'Pdf Book Download - Read Pdf Book': ['Pdf Book Download - Read Pdf Book',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '1322',
#   '3.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'May 28, 2018',
#   '6.0',
#   '4.0.3 and up'],
#  'Free Book Reader': ['Free Book Reader',
#   'BOOKS_AND_REFERENCE',
#   '3.4',
#   '1680',
#   '4.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 20, 2016',
#   '3.05',
#   '4.0.3 and up'],
#  'eBoox new: Reader for fb2 epub zip books': ['eBoox new: Reader for fb2 epub zip books',
#   'BOOKS_AND_REFERENCE',
#   '4.9',
#   '2739',
#   '21M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 17, 2018',
#   '2.0',
#   '3.0 and up'],
#  'Only 30 days in English, the guideline is guaranteed': ['Only 30 days in English, the guideline is guaranteed',
#   'BOOKS_AND_REFERENCE',
#   '4.6',
#   '1065',
#   '2.3M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 16, 2018',
#   '1.5',
#   '3.0 and up'],
#  'Moon+ Reader': ['Moon+ Reader',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '233757',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'May 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  "SH-02J Owner's Manual (Android 8.0)": ["SH-02J Owner's Manual (Android 8.0)",
#   'BOOKS_AND_REFERENCE',
#   'NaN',
#   '2',
#   '7.2M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'June 15, 2018',
#   '3.0',
#   '6.0 and up'],
#  'English-Myanmar Dictionary': ['English-Myanmar Dictionary',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '8788',
#   '10M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 28, 2018',
#   '2.5.3',
#   '4.0 and up'],
#  'Golden Dictionary (EN-AR)': ['Golden Dictionary (EN-AR)',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '51269',
#   '6.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 19, 2018',
#   '7.0.4.6',
#   '4.2 and up'],
#  'All Language Translator Free': ['All Language Translator Free',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '30105',
#   '2.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'July 29, 2018',
#   '1.15',
#   '4.0.3 and up'],
#  'Azpen eReader': ['Azpen eReader',
#   'BOOKS_AND_REFERENCE',
#   '3.5',
#   '156',
#   '42M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'February 15, 2018',
#   '3.1.7.9',
#   '2.2 and up'],
#  'URBANO V 02 instruction manual': ['URBANO V 02 instruction manual',
#   'BOOKS_AND_REFERENCE',
#   'NaN',
#   '114',
#   '7.3M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Books & Reference',
#   'August 7, 2015',
#   '1.1',
#   '5.1 and up'],
#  'English Dictionary - Offline': ['English Dictionary - Offline',
#   'BOOKS_AND_REFERENCE',
#   '4.4',
#   '341234',
#   '30M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Books & Reference',
#   'March 20, 2018',
#   '3.9.1',
#   '4.2 and up'],
#  'Visual Voicemail by MetroPCS': ['Visual Voicemail by MetroPCS',
#   'BUSINESS',
#   '4.1',
#   '16129',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Indeed Job Search': ['Indeed Job Search',
#   'BUSINESS',
#   '4.3',
#   '674730',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'May 21, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Uber Driver': ['Uber Driver',
#   'BUSINESS',
#   '4.4',
#   '1254730',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'ADP Mobile Solutions': ['ADP Mobile Solutions',
#   'BUSINESS',
#   '4.3',
#   '85185',
#   '29M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 17, 2018',
#   '3.4.2',
#   '5.0 and up'],
#  'Snag - Jobs Hiring Now': ['Snag - Jobs Hiring Now',
#   'BUSINESS',
#   '4.3',
#   '32584',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'May 4, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Docs To Go™ Free Office Suite': ['Docs To Go™ Free Office Suite',
#   'BUSINESS',
#   '4.1',
#   '217730',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'April 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Google My Business': ['Google My Business',
#   'BUSINESS',
#   '4.4',
#   '70991',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 24, 2018',
#   '2.19.0.204537701',
#   '4.4 and up'],
#  'OfficeSuite : Free Office + PDF Editor': ['OfficeSuite : Free Office + PDF Editor',
#   'BUSINESS',
#   '4.3',
#   '1002861',
#   '35M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 2, 2018',
#   '9.7.14188',
#   '4.1 and up'],
#  'USPS MOBILE®': ['USPS MOBILE®',
#   'BUSINESS',
#   '3.9',
#   '16589',
#   '9.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 14, 2018',
#   '4.9.10',
#   '4.0.3 and up'],
#  'Job Search by ZipRecruiter': ['Job Search by ZipRecruiter',
#   'BUSINESS',
#   '4.8',
#   '148945',
#   '25M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 19, 2018',
#   '5.2.8',
#   '5.0 and up'],
#  'Curriculum vitae App CV Builder Free Resume Maker': ['Curriculum vitae App CV Builder Free Resume Maker',
#   'BUSINESS',
#   '4.5',
#   '4571',
#   '3.9M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 8, 2018',
#   '3.3',
#   '4.1 and up'],
#  'Google Primer': ['Google Primer',
#   'BUSINESS',
#   '4.4',
#   '62272',
#   '18M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'June 26, 2018',
#   '3.550.2',
#   '4.1 and up'],
#  'Alba Heaven - Alvarez Job Portal Services': ['Alba Heaven - Alvarez Job Portal Services',
#   'BUSINESS',
#   '4.0',
#   '8941',
#   '12M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 31, 2018',
#   '4.6.30',
#   '4.0.3 and up'],
#  'SuperLivePro': ['SuperLivePro',
#   'BUSINESS',
#   '4.3',
#   '46353',
#   '21M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'April 13, 2016',
#   '2.8',
#   '1.5 and up'],
#  'Facebook Pages Manager': ['Facebook Pages Manager',
#   'BUSINESS',
#   '4.0',
#   '1279800',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'August 6, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'OfficeSuite Pro + PDF (Trial)': ['OfficeSuite Pro + PDF (Trial)',
#   'BUSINESS',
#   '4.2',
#   '88073',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 9, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'My Space - Employment Center': ['My Space - Employment Center',
#   'BUSINESS',
#   '4.5',
#   '67000',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 17, 2018',
#   'Varies with device',
#   '4.3 and up'],
#  'Box': ['Box',
#   'BUSINESS',
#   '4.2',
#   '159872',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'July 31, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Polaris Office for LG': ['Polaris Office for LG',
#   'BUSINESS',
#   '4.2',
#   '30847',
#   '55M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Business',
#   'February 8, 2018',
#   '7.3.21',
#   '4.1 and up'],
#  'Call Blocker': ['Call Blocker',
#   'BUSINESS',
#   '4.6',
#   '188841',
#   '3.2M',
#   '5,000,000+',
#   'Free',
#   '0',
# ...
#   'FINANCE',
#   '4.3',
#   '34861',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Trading 212 - Forex, Stocks, CFDs': ['Trading 212 - Forex, Stocks, CFDs',
#   'FINANCE',
#   '4.3',
#   '37580',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'August 1, 2018',
#   '4.5.2.1',
#   '4.4 and up'],
#  'Moneycontrol – Stocks, Sensex, Mutual Funds, IPO': ['Moneycontrol – Stocks, Sensex, Mutual Funds, IPO',
#   'FINANCE',
#   '4.4',
#   '281635',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'August 6, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Current debit card and app made for teens': ['Current debit card and app made for teens',
#   'FINANCE',
#   '4.3',
#   '685',
#   '21M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'August 3, 2018',
#   '3.0.22',
#   '4.4 and up'],
#  'Betterment': ['Betterment',
#   'FINANCE',
#   '4.4',
#   '3780',
#   '11M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'August 3, 2018',
#   '6.0.6',
#   '5.0 and up'],
#  'Citizens Bank Mobile Banking': ['Citizens Bank Mobile Banking',
#   'FINANCE',
#   '4.1',
#   '15192',
#   '38M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'May 23, 2018',
#   '4.2.1',
#   '4.1 and up'],
#  'GoBank': ['GoBank',
#   'FINANCE',
#   '4.4',
#   '5950',
#   '12M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'June 1, 2018',
#   '2.131',
#   '4.1 and up'],
#  'NetSpend Prepaid': ['NetSpend Prepaid',
#   'FINANCE',
#   '4.2',
#   '15993',
#   '45M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'May 9, 2018',
#   '4.10.0',
#   '4.4 and up'],
#  'BBVA Compass Banking': ['BBVA Compass Banking',
#   'FINANCE',
#   '4.3',
#   '5905',
#   '50M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 27, 2018',
#   '6.0.2',
#   '4.4 and up'],
#  'BankMobile Vibe App': ['BankMobile Vibe App',
#   'FINANCE',
#   '4.3',
#   '14627',
#   '23M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 9, 2018',
#   '5.1',
#   '4.1 and up'],
#  'Netspend Skylight ONE': ['Netspend Skylight ONE',
#   'FINANCE',
#   '3.9',
#   '1098',
#   '46M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'May 9, 2018',
#   '4.10.0',
#   '4.4 and up'],
#  'ACE Elite': ['ACE Elite',
#   'FINANCE',
#   '4.1',
#   '2898',
#   '45M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'May 9, 2018',
#   '4.10.0',
#   '4.4 and up'],
#  'U.S. Bank': ['U.S. Bank',
#   'FINANCE',
#   '4.1',
#   '70782',
#   '50M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 25, 2018',
#   '2.34.29',
#   '4.0.3 and up'],
#  'Huntington Mobile': ['Huntington Mobile',
#   'FINANCE',
#   '4.2',
#   '11264',
#   '24M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'June 26, 2018',
#   '5.2.203',
#   '4.2 and up'],
#  'USAA Mobile': ['USAA Mobile',
#   'FINANCE',
#   '4.5',
#   '100997',
#   '33M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 27, 2018',
#   '8.44.2',
#   '5.0 and up'],
#  'Associated Credit Union Mobile': ['Associated Credit Union Mobile',
#   'FINANCE',
#   '4.7',
#   '3290',
#   '12M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'May 30, 2018',
#   '5.9.1.0',
#   '5.0 and up'],
#  'Bank of America Mobile Banking': ['Bank of America Mobile Banking',
#   'FINANCE',
#   '4.4',
#   '341090',
#   '53M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 31, 2018',
#   '7.8.8',
#   '4.4 and up'],
#  'USE Credit Union Mobile': ['USE Credit Union Mobile',
#   'FINANCE',
#   '4.6',
#   '964',
#   '14M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'June 12, 2018',
#   '5.9.1.0',
#   '5.0 and up'],
#  'Discover Mobile': ['Discover Mobile',
#   'FINANCE',
#   '4.6',
#   '87951',
#   '68M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 23, 2018',
#   '9.7.0',
#   '4.1 and up'],
#  'Amex Mobile': ['Amex Mobile',
#   'FINANCE',
#   '4.3',
#   '24729',
#   '32M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'August 3, 2018',
#   '6.7.0',
#   '5.0 and up'],
#  'Citi Mobile®': ['Citi Mobile®',
#   'FINANCE',
#   '4.0',
#   '78306',
#   '46M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 31, 2018',
#   '9.9.0',
#   '4.4 and up'],
#  'Navy Federal Credit Union': ['Navy Federal Credit Union',
#   'FINANCE',
#   '4.4',
#   '43313',
#   '40M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 9, 2018',
#   '5.16.2',
#   '4.1 and up'],
#  'Chase Mobile': ['Chase Mobile',
#   'FINANCE',
#   '4.6',
#   '1374549',
#   '32M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 23, 2018',
#   '3.52',
#   '5.0 and up'],
#  'HDFC Bank MobileBanking': ['HDFC Bank MobileBanking',
#   'FINANCE',
#   '4.2',
#   '208463',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'July 26, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Barclays US for Android': ['Barclays US for Android',
#   'FINANCE',
#   '4.1',
#   '6998',
#   '24M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Finance',
#   'August 1, 2018',
#   '6.29.37589',
#   '5.0 and up'],
#  "McDonald's": ["McDonald's",
#   'FOOD_AND_DRINK',
#   '3.6',
#   '145646',
#   '42M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 31, 2018',
#   '5.15.0',
#   '4.4 and up'],
#  'Easy and Fast Recipes': ['Easy and Fast Recipes',
#   'FOOD_AND_DRINK',
#   'NaN',
#   '95',
#   '12M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'January 6, 2018',
#   '3.0.1',
#   '2.3 and up'],
#  'Cookpad - FREE recipe search makes fun cooking · musical making!': ['Cookpad - FREE recipe search makes fun cooking · musical making!',
#   'FOOD_AND_DRINK',
#   '4.1',
#   '64784',
#   '13M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'August 2, 2018',
#   '18.6.0.10',
#   '5.0 and up'],
#  'DELISH KITCHEN - FREE recipe movies make food fun and easy!': ['DELISH KITCHEN - FREE recipe movies make food fun and easy!',
#   'FOOD_AND_DRINK',
#   '4.6',
#   '32997',
#   '13M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'August 4, 2018',
#   '2.2.7',
#   '4.1 and up'],
#  'Sumine side dish - dish recipe side dish': ['Sumine side dish - dish recipe side dish',
#   'FOOD_AND_DRINK',
#   'NaN',
#   '82',
#   '4.9M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'June 23, 2018',
#   '1.1',
#   '4.1 and up'],
#  'Easy Recipes': ['Easy Recipes',
#   'FOOD_AND_DRINK',
#   '4.7',
#   '2707',
#   '8.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'May 15, 2018',
#   '2.12',
#   '4.0.3 and up'],
#  'Delicious Recipes': ['Delicious Recipes',
#   'FOOD_AND_DRINK',
#   '4.7',
#   '129737',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Food & Drink',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Tastely': ['Tastely',
#   'FOOD_AND_DRINK',
#   '4.7',
#   '611136',
#   '19M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 13, 2018',
#   '3.2.0d',
#   '4.0.3 and up'],
#  'Pastry & Cooking (Without Net)': ['Pastry & Cooking (Without Net)',
#   'FOOD_AND_DRINK',
#   '4.7',
#   '6118',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 7, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Frigo Magic: Easy recipe idea and anti-waste': ['Frigo Magic: Easy recipe idea and anti-waste',
#   'FOOD_AND_DRINK',
#   '4.1',
#   '2473',
#   '14M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 28, 2018',
#   '3.1.5',
#   '4.4 and up'],
#  "McDonald's - McDonald's Japan": ["McDonald's - McDonald's Japan",
#   'FOOD_AND_DRINK',
#   '3.4',
#   '109784',
#   '64M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'August 3, 2018',
#   '4.0.30',
#   '4.0.3 and up'],
#  'Debonairs Pizza': ['Debonairs Pizza',
#   'FOOD_AND_DRINK',
#   '3.8',
#   '3320',
#   '8.4M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'August 4, 2018',
#   '1.9.117',
#   '4.0.3 and up'],
#  'Popeyes® App': ['Popeyes® App',
#   'FOOD_AND_DRINK',
#   '3.7',
#   '61',
#   '11M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 23, 2018',
#   '1.0.2',
#   '4.1 and up'],
#  "Dunkin' Donuts": ["Dunkin' Donuts",
#   'FOOD_AND_DRINK',
#   '4.2',
#   '68270',
#   '66M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'June 20, 2018',
#   '5.0.0',
#   '4.4 and up'],
#  'Pyaterochka': ['Pyaterochka',
#   'FOOD_AND_DRINK',
#   '3.1',
#   '8412',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 19, 2018',
#   'Varies with device',
#   '4.4 and up'],
#  'Refreshing app Free application that can use deal coupons': ['Refreshing app Free application that can use deal coupons',
#   'FOOD_AND_DRINK',
#   '3.5',
#   '10741',
#   '41M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 23, 2018',
#   '5.2.2',
#   '4.2 and up'],
#  'Simple Recipes': ['Simple Recipes',
#   'FOOD_AND_DRINK',
#   '4.7',
#   '3803',
#   '15M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'February 22, 2018',
#   '1.6',
#   '4.0 and up'],
#  'Grubhub: Food Delivery': ['Grubhub: Food Delivery',
#   'FOOD_AND_DRINK',
#   '4.5',
#   '155944',
#   '35M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'August 2, 2018',
#   '7.12',
#   '5.0 and up'],
#  'Panera Bread': ['Panera Bread',
#   'FOOD_AND_DRINK',
#   '4.2',
#   '10225',
#   '36M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'August 6, 2018',
#   '4.4.2',
#   '5.0 and up'],
#  'Chick-fil-A': ['Chick-fil-A',
#   'FOOD_AND_DRINK',
#   '4.3',
#   '28009',
#   '17M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'August 3, 2018',
#   '6.0.1',
#   '5.0 and up'],
#  'hellofood - Food Delivery': ['hellofood - Food Delivery',
#   'FOOD_AND_DRINK',
#   '4.0',
#   '43614',
#   '25M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'October 12, 2016',
#   '2.14.36',
#   '4.0.3 and up'],
#  'Starbucks': ['Starbucks',
#   'FOOD_AND_DRINK',
#   '4.5',
#   '455496',
#   '35M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'August 1, 2018',
#   '4.11.1',
#   '4.4 and up'],
#  'Easy and quick desserts': ['Easy and quick desserts',
#   'FOOD_AND_DRINK',
#   '4.6',
#   '1398',
#   '10M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Food & Drink',
#   'June 14, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  "Domino's Pizza USA": ["Domino's Pizza USA",
#   'FOOD_AND_DRINK',
#   '4.7',
#   '1032935',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 20, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Chef - Recipes & Cooking': ['Chef - Recipes & Cooking',
#   'FOOD_AND_DRINK',
#   '4.1',
#   '32405',
#   '12M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 3, 2018',
#   '3.3.21',
#   '4.1 and up'],
#  'Delivery Club-food delivery: pizza, sushi, burger, salad': ['Delivery Club-food delivery: pizza, sushi, burger, salad',
#   'FOOD_AND_DRINK',
#   '4.3',
#   '151080',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 27, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'HungerStation': ['HungerStation',
#   'FOOD_AND_DRINK',
#   '3.8',
#   '22513',
#   '11M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'May 21, 2018',
#   '5.3.8',
#   '4.0.3 and up'],
#  'Delivery yogi.': ['Delivery yogi.',
#   'FOOD_AND_DRINK',
#   '4.4',
#   '90042',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 18, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Delivery trough - delivery trough delivery trough': ['Delivery trough - delivery trough delivery trough',
#   'FOOD_AND_DRINK',
#   '4.3',
#   '58316',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Dr. Oetker recipe ideas': ['Dr. Oetker recipe ideas',
#   'FOOD_AND_DRINK',
#   '4.2',
#   '8509',
#   '17M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 12, 2018',
#   '3.5.5',
#   '4.0.3 and up'],
#  'SONIC Drive-In': ['SONIC Drive-In',
#   'FOOD_AND_DRINK',
#   '4.3',
#   '19373',
#   '43M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 31, 2018',
#   '3.3.6',
#   '4.4 and up'],
#  'SUBWAY®': ['SUBWAY®',
#   'FOOD_AND_DRINK',
#   '3.8',
#   '21381',
#   '41M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 24, 2018',
#   '7.9.0.0',
#   '4.4 and up'],
#  'GialloZafferano: Recipes': ['GialloZafferano: Recipes',
#   'FOOD_AND_DRINK',
#   '4.3',
#   '30224',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'May 28, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Dairy Queen': ['Dairy Queen',
#   'FOOD_AND_DRINK',
#   '3.6',
#   '742',
#   '43M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 25, 2018',
#   '2.1.0',
#   '4.1 and up'],
#  '9th stage': ['9th stage',
#   'FOOD_AND_DRINK',
#   '4.5',
#   '454',
#   '16M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'March 28, 2018',
#   '2.0.0',
#   '4.0.3 and up'],
#  'OpenRice': ['OpenRice',
#   'FOOD_AND_DRINK',
#   '3.6',
#   '14952',
#   '39M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'June 8, 2018',
#   '5.8.5',
#   '4.1 and up'],
#  'SarashpazPapion (Cooking with Chef Bowls)': ['SarashpazPapion (Cooking with Chef Bowls)',
#   'FOOD_AND_DRINK',
#   '4.8',
#   '1250',
#   '13M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 28, 2018',
#   '3.2.7',
#   '4.1 and up'],
#  'Little Caesars': ['Little Caesars',
#   'FOOD_AND_DRINK',
#   '3.3',
#   '1726',
#   '30M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'July 19, 2018',
#   '4.26',
#   '4.4 and up'],
#  'Recipes Pastries and homemade pies More than 500 recipes for pastries': ['Recipes Pastries and homemade pies More than 500 recipes for pastries',
#   'FOOD_AND_DRINK',
#   '4.7',
#   '14065',
#   '7.1M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'June 12, 2018',
#   '1.2.2',
#   '4.1 and up'],
#  'Om Waleed Sweets': ['Om Waleed Sweets',
#   'FOOD_AND_DRINK',
#   '4.6',
#   '556',
#   '23M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Food & Drink',
#   'January 25, 2018',
#   '2.0',
#   '4.0 and up'],
#  'Eat Fast Prepare "Without Internet"': ['Eat Fast Prepare "Without Internet"',
#   'FOOD_AND_DRINK',
#   '4.6',
#   '4925',
#   '17M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'June 10, 2018',
#   '3.6.6',
#   '4.0.3 and up'],
#  'Wendy’s – Food and Offers': ['Wendy’s – Food and Offers',
#   'FOOD_AND_DRINK',
#   '3.4',
#   '6512',
#   '18M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'April 12, 2018',
#   '5.7.0',
#   '4.4 and up'],
#  'My Recipes Cookbook : RecetteTek': ['My Recipes Cookbook : RecetteTek',
#   'FOOD_AND_DRINK',
#   '4.6',
#   '11707',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'June 24, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'Healthy Recipes Free': ['Healthy Recipes Free',
#   'FOOD_AND_DRINK',
#   '4.0',
#   '1077',
#   '17M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'October 18, 2017',
#   '3.2.0',
#   '4.0.3 and up'],
#  'Cookbook Recipes': ['Cookbook Recipes',
#   'FOOD_AND_DRINK',
#   '4.1',
#   '46539',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Food & Drink',
#   'July 23, 2018',
#   'Varies with device',
#   'Varies with device'],
#  'ChefTap Recipes & Grocery List': ['ChefTap Recipes & Grocery List',
#   'FOOD_AND_DRINK',
#   '4.5',
#   '9066',
#   '15M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'April 25, 2018',
#   '4.0.0.427',
#   '5.1 and up'],
#  'Recipe Keeper': ['Recipe Keeper',
#   'FOOD_AND_DRINK',
#   '4.4',
#   '1962',
#   '22M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'June 27, 2018',
#   '3.17.1.0',
#   '4.1 and up'],
#  'My CookBook (Recipe Manager)': ['My CookBook (Recipe Manager)',
#   'FOOD_AND_DRINK',
#   '4.5',
#   '22071',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Food & Drink',
#   'June 29, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ...}
